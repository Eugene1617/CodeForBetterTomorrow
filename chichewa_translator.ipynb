# %% [markdown]
# <a href="https://colab.research.google.com/github/Eugene1617/CodeForBetterTomorrow/blob/main/chichewa_translator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data='/content/sentences_6000_chichewa.csv'
df=pd.read_csv(data)
df
# Out:
#         id    category                                   english_sentence  \
# 0        1    business         My father met with the client at midnight.
# 1        2  technology              You fixed the problem with a network.
# 2        3  directions           My father asked how to reach the church.
# 3        4    business      The manager signed the contract this evening.
# 4        5  technology      She connected to a smartphone at the village.
# ...    ...         ...                                                ...
# 5995  5996     culture  My friend cooked a traditional dish for the ce...
# 5996  5997      health         The driver takes the medicine twice a day.
# 5997  5998      travel  The student packed a bag for the trip to the l...
# 5998  5999     animals               I trained a lion to follow commands.
# 5999  6000      sports                         You joined a cycling team.
#
#                                    chichewa_translation
# ...

# %%
display(df.describe())
# Out:
#                 id
# count  6000.000000
# mean   3000.500000
# std    1732.195139
# min       1.000000
# 25%    1500.750000
# 50%    3000.500000
# 75%    4500.250000
# max    6000.000000

# %%
category_counts = df['category'].value_counts()
display(category_counts)
# Out:
# category
# shopping      400
# travel        378
# emotions      377
# food          376
# sports        375
# finance       374
# technology    370
# directions    369
# daily_life    360
# education     309
# business      303
# nature        288
# weather       274
# health        267
# work          259
# animals       252
# family        248
# culture       238
# questions      97
# greetings      76
# commands       10
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(12, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')
plt.title('Number of Sentences per Category')
plt.xlabel('Category')
plt.ylabel('Number of Sentences')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_947/959242074.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')

# %%
missing_values = df.isnull().sum()
display(missing_values)
# Out:
# id                      0
# category                0
# english_sentence        0
# chichewa_translation    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    6000 non-null   int64
#  1   category              6000 non-null   object
#  2   english_sentence      6000 non-null   object
#  3   chichewa_translation  6000 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 187.6+ KB

# %%
from numpy._core.defchararray import index
import re

english = tagert[col[3]].str.lower()
english = english.str.strip()
english = english.str.replace(r"\s+", " ", regex=True)
english = english.str.replace(r"[\r\n]+", " ", regex=True)
english = english.str.replace(r"\s+([,.!?;:])", r"\1", regex=True)
english = english.str.strip()
english = tagert[col[3]].str.lower()
english = english.str.strip()
english = english.str.replace(r"\s+", " ", regex=True)
english = english.str.replace(r"[\r\n]+", " ", regex=True)
english = english.str.replace(r"\s+([,.!?;:])", r"\1", regex=True)
english = english.str.strip()

tagert[col[3]] = english
tagert[col[3]] = english
tagert.to_csv('cleaned_data_transrator.csv',index=False)
# Out:
# /tmp/ipykernel_947/2558792866.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tagert[col[3]] = english
# /tmp/ipykernel_947/2558792866.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tagert[col[3]] = english

# %%
tagert.head()
# Out:
#                                 english_sentence  \
# 0     My father met with the client at midnight.
# 1          You fixed the problem with a network.
# 2       My father asked how to reach the church.
# 3  The manager signed the contract this evening.
# 4  She connected to a smartphone at the village.
#
#                                 chichewa_translation
# 0  bambo anga anakumana ndi kasitomala pakati pa ...
# 1                          wakonza vuto la netiweki.
# 2  bambo anga anafunsa mmene angafikire ku tchali...
# 3               manaja anasaina pangano madzulo ano.
# 4                  iye analumikizana ndi simatifoni.

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=tagert)
# Out:
# https://docs.google.com/spreadsheets/d/1BJaKFqMlkrIayieL4nRspUfrwJDjDZX0GIdp5rZzyzw/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1BJaKFqMlkrIayieL4nRspUfrwJDjDZX0GIdp5rZzyzw/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
